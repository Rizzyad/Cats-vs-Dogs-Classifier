# %% [markdown]
# <a href="https://colab.research.google.com/github/Rizzyad/Cats-vs-Dogs-Classifier/blob/main/Cls_Cat%26Dogs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget "https://storage.googleapis.com/kaggle-data-sets/2716794/4748798/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230524%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230524T130258Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=..."
# Out:
# The name is too long, 767 chars total.
# Trying to shorten...
# New name is archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com@kaggle-161607.iam.gserviceaccount.com%2F20230524%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230524T130258Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=hos.
# --2023-05-25 04:12:15--  https://storage.googleapis.com/kaggle-data-sets/2716794/4748798/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230524%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230524T130258Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.6.128, 108.177.112.128, 74.125.124.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.6.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 67566406 (64M) [application/zip]
# ...

# %%
# !unzip -q "archive.zip"

# %%
# !ls "catdog"
# Out:
# ls: cannot access 'catdog': No such file or directory

# %%
# !ls "catdog/train/"
# Out:
# ls: cannot access 'catdog/train/': No such file or directory

# %%
# !ls "catdog/train/cats"
# Out:
# ls: cannot access 'catdog/train/cats': No such file or directory

# %%
import os

for dirpath, dirnames, filenames in os.walk("catdog"):
  print(f"Ada {len(dirnames)} direktori dan {len(filenames)} gambar di '{dirpath}'. ")

# %%
import pathlib
import numpy as np

data_dir = pathlib.Path("catdog/train/")
class_names = np.array(sorted([item.name for item in data_dir.glob('*')]))

print(class_names)
# Out:
# []

# %%
import random
import matplotlib.pyplot as plt
import matplotlib.image as pltimg

def view_random_image(target_dir, target_class):
  target_folder = os.path.join(target_dir, target_class)
  random_image = random.choice(os.listdir(target_folder))

  img_path = os.path.join(target_folder, random_image)
  img = plt.imread(img_path)

  plt.imshow(img)
  plt.title(target_class)
  plt.axis(False)

  print(f"Image shape: {img.shape}")

  return img

# %%
img_cat = view_random_image("catdog/train/", "cats")
# Out:
# Image shape: (183, 275, 3)

# %%
img_cat
# Out:
# array([[[233, 240, 250],
#         [233, 240, 250],
#         [233, 240, 250],
#         ...,
#         [ 11,  11,   9],
#         [ 11,  11,   9],
#         [ 11,  11,   9]],
#
#        [[233, 240, 250],
#         [233, 240, 250],
#         [233, 240, 250],
#         ...,
#         [ 11,  11,   9],
#         [ 11,  11,   9],
#         [ 11,  11,   9]],
#
#        [[233, 240, 250],
#         [233, 240, 250],
#         [233, 240, 250],
#         ...,
#         [ 11,  11,   9],
#         [ 11,  11,   9],
#         [ 11,  11,   9]],
#
#        ...,
#
#        [[124, 111, 121],
#         [122, 109, 119],
#         [119, 106, 116],
#         ...,
#         [ 21,  20,  25],
#         [ 21,  20,  25],
#         [ 21,  20,  25]],
#
#        [[125, 112, 122],
#         [122, 109, 119],
#         [118, 105, 115],
#         ...,
#         [ 20,  19,  24],
#         [ 20,  19,  24],
#         [ 20,  19,  24]],
#
#        [[126, 113, 123],
#         [122, 109, 119],
#         [117, 104, 114],
# ...

# %%
img_dog = view_random_image("catdog/train", "dogs")
# Out:
# Image shape: (635, 640, 3)

# %%
img_dog
# Out:
# array([[[131, 210, 205],
#         [131, 210, 205],
#         [131, 210, 205],
#         ...,
#         [131, 210, 205],
#         [131, 210, 205],
#         [131, 210, 205]],
#
#        [[131, 210, 205],
#         [131, 210, 205],
#         [131, 210, 205],
#         ...,
#         [131, 210, 205],
#         [131, 210, 205],
#         [131, 210, 205]],
#
#        [[131, 210, 205],
#         [131, 210, 205],
#         [131, 210, 205],
#         ...,
#         [131, 210, 205],
#         [131, 210, 205],
#         [131, 210, 205]],
#
#        ...,
#
#        [[137, 213, 209],
#         [137, 213, 209],
#         [137, 213, 209],
#         ...,
#         [135, 211, 207],
#         [135, 211, 207],
#         [135, 211, 207]],
#
#        [[137, 213, 209],
#         [137, 213, 209],
#         [137, 213, 209],
#         ...,
#         [135, 211, 207],
#         [135, 211, 207],
#         [135, 211, 207]],
#
#        [[137, 213, 209],
#         [137, 213, 209],
#         [137, 213, 209],
# ...

# %%
train_dir = "catdog/train/"
test_dir = "catdog/test/"

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen_augmented = ImageDataGenerator(rescale=1/255.,
                                             rotation_range=20,
                                             shear_range=0.2,
                                             zoom_range=0.2,
                                             width_shift_range=0.2,
                                             height_shift_range=0.2,
                                             horizontal_flip=True)

train_datagen = ImageDataGenerator(rescale=1/255.)

test_datagen = ImageDataGenerator(rescale=1/255.)

# %%
train_data_augmented = train_datagen_augmented.flow_from_directory(train_dir,
                                                                   batch_size=32,
                                                                   target_size=(224,224),
                                                                   class_mode='binary',
                                                                   seed=42,
                                                                   shuffle=False)

train_data = train_datagen.flow_from_directory(train_dir,
                                            batch_size=32,
                                            target_size=(224,224),
                                            class_mode='binary',
                                            seed=42,
                                            shuffle=False)

test_data = test_datagen.flow_from_directory(test_dir,
                                             batch_size=32,
                                             target_size=(224,224),
                                             class_mode='binary',
                                             seed=42,
                                             shuffle=False)
# Out:
# Found 557 images belonging to 2 classes.
# Found 557 images belonging to 2 classes.
# Found 140 images belonging to 2 classes.

# %%
images, labels = train_data.next()
augmented_images, augmented_labels = train_data_augmented.next()

print(f"{len(images), len(labels)}")
print(f"{len(augmented_images), len(augmented_labels)}")
# Out:
# (32, 32)
# (32, 32)

# %%
images[0], images[0].shape
# Out:
# (array([[[0.6862745 , 0.72156864, 0.70980394],
#          [0.627451  , 0.6627451 , 0.6509804 ],
#          [0.6509804 , 0.6862745 , 0.6745098 ],
#          ...,
#          [0.6431373 , 0.49803925, 0.427451  ],
#          [0.654902  , 0.5176471 , 0.4431373 ],
#          [0.627451  , 0.4901961 , 0.4156863 ]],
#
#         [[0.7019608 , 0.7372549 , 0.7254902 ],
#          [0.64705884, 0.68235296, 0.67058825],
#          [0.6392157 , 0.6745098 , 0.6627451 ],
#          ...,
#          [0.65882355, 0.5137255 , 0.4431373 ],
#          [0.69411767, 0.5568628 , 0.48235297],
#          [0.5882353 , 0.45098042, 0.37647063]],
#
#         [[0.654902  , 0.6901961 , 0.6784314 ],
#          [0.67058825, 0.7058824 , 0.69411767],
#          [0.68235296, 0.7176471 , 0.7058824 ],
#          ...,
#          [0.63529414, 0.4901961 , 0.41960788],
#          [0.60784316, 0.47058827, 0.39607847],
#          [0.61960787, 0.48235297, 0.40784317]],
#
#         ...,
#
# ...

# %%
random_number = random.randint(0, 32)

plt.imshow(images[random_number])
plt.title(f"Original Image")
plt.axis(False)

plt.figure()
plt.imshow(augmented_images[random_number])
plt.title(f"Augmented Image")
plt.axis(False)
print(images.shape)
# Out:
# (32, 224, 224, 3)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Activation, Flatten, Dense

# %%
model_1 = Sequential([
    Conv2D(10, 3, activation='relu', input_shape=(224,224,3)),
    Conv2D(10, 3, activation='relu'),
    MaxPool2D(2, padding='valid'),
    Conv2D(10, 3, activation='relu'),
    Conv2D(10, 3, activation='relu'),
    MaxPool2D(2, padding='valid'),
    Flatten(),
    Dense(1, activation='sigmoid')
])

model_1.compile(
    loss = 'binary_crossentropy',
    optimizer = 'adam',
    metrics = ['accuracy']
)

model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 222, 222, 10)      280
#
#  conv2d_1 (Conv2D)           (None, 220, 220, 10)      910
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 10)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 108, 108, 10)      910
#
#  conv2d_3 (Conv2D)           (None, 106, 106, 10)      910
#
#  max_pooling2d_1 (MaxPooling  (None, 53, 53, 10)       0
#  2D)
#
#  flatten (Flatten)           (None, 28090)             0
#
#  dense (Dense)               (None, 1)                 28091
#
# ...
# Total params: 31,101
# Trainable params: 31,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_data_augmented_shuffled = train_datagen_augmented.flow_from_directory(train_dir,
                                                                            batch_size=32,
                                                                            target_size=(224,224),
                                                                            class_mode='binary',
                                                                            seed=42,
                                                                            shuffle=True)
# Out:
# Found 557 images belonging to 2 classes.

# %%
len(train_data_augmented_shuffled), len(test_data)
# Out:
# (18, 5)

# %%
history_1 = model_1.fit(train_data_augmented_shuffled,
                        epochs=5,
                        steps_per_epoch=len(train_data_augmented_shuffled),
                        validation_data=test_data,
                        validation_steps=len(test_data))
# Out:
# Epoch 1/5
# 18/18 [==============================] - 28s 837ms/step - loss: 0.7038 - accuracy: 0.5242 - val_loss: 0.6944 - val_accuracy: 0.5000
# Epoch 2/5
# 18/18 [==============================] - 15s 833ms/step - loss: 0.6938 - accuracy: 0.5117 - val_loss: 0.6931 - val_accuracy: 0.5357
# Epoch 3/5
# 18/18 [==============================] - 15s 814ms/step - loss: 0.6926 - accuracy: 0.5224 - val_loss: 0.6925 - val_accuracy: 0.6000
# Epoch 4/5
# 18/18 [==============================] - 15s 855ms/step - loss: 0.6912 - accuracy: 0.5135 - val_loss: 0.6921 - val_accuracy: 0.5000
# Epoch 5/5
# 18/18 [==============================] - 15s 808ms/step - loss: 0.6925 - accuracy: 0.5224 - val_loss: 0.6937 - val_accuracy: 0.5357

# %%
import pandas as pd

pd.DataFrame(history_1.history).plot(figsize=(10,7))
# Out:
# <Axes: >

# %%
model_2  = Sequential([
    Conv2D(32, 7, activation='relu', input_shape=(224,224,3), padding='same'),
    MaxPool2D(2),
    Conv2D(64, 5, activation='relu', padding='same'),
    MaxPool2D(2),
    Conv2D(128, 3, activation='relu', padding='same'),
    MaxPool2D(2),
    Flatten(),
    Dense(1, activation='sigmoid')
])

model_2.compile(
    loss = 'binary_crossentropy',
    optimizer = 'adam',
    metrics = ['accuracy']
)

history_2 = model_2.fit(train_data_augmented_shuffled,
                        epochs=10,
                        steps_per_epoch=len(train_data_augmented_shuffled),
                        validation_data=test_data,
                        validation_steps=len(test_data))
# Out:
# Epoch 1/10
# 18/18 [==============================] - 20s 920ms/step - loss: 0.9010 - accuracy: 0.4937 - val_loss: 0.7112 - val_accuracy: 0.5000
# Epoch 2/10
# 18/18 [==============================] - 15s 840ms/step - loss: 0.6979 - accuracy: 0.5224 - val_loss: 0.6931 - val_accuracy: 0.5071
# Epoch 3/10
# 18/18 [==============================] - 15s 850ms/step - loss: 0.6931 - accuracy: 0.5045 - val_loss: 0.7424 - val_accuracy: 0.5000
# Epoch 4/10
# 18/18 [==============================] - 16s 868ms/step - loss: 0.6940 - accuracy: 0.5386 - val_loss: 0.6900 - val_accuracy: 0.5786
# Epoch 5/10
# 18/18 [==============================] - 17s 944ms/step - loss: 0.6916 - accuracy: 0.5242 - val_loss: 0.6890 - val_accuracy: 0.5357
# Epoch 6/10
# 18/18 [==============================] - 15s 833ms/step - loss: 0.6911 - accuracy: 0.5440 - val_loss: 0.6892 - val_accuracy: 0.5857
# Epoch 7/10
# ...
